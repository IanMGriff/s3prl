# %% [markdown]
# <a href="https://colab.research.google.com/github/IanMGriff/s3prl/blob/master/Test_s3plr_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# /content
